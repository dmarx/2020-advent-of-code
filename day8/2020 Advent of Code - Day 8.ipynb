# %% [markdown]
# # Part 1

# %%
#import networkx as nx

# %%
def parse_instruction(line):
    #raise NotImplementedError
    op, val = line.strip().split()
    val = int(val)
    return op, val

class ExecutionGraph:
    def __init__(self, code_str):
        self.code_str = code_str
        self.instructions = []
        self.visited = set()
        #self.g_exec = nx.DiGraph()
        
        self.current_location = 0
        self.last_executed = None
        self.acc = 0
        
        self.parse_code()

    def parse_code(self):
        for line in self.code_str.split('\n'):
            line = line.strip()
            if not line:
                continue
            op, val = parse_instruction(line)
            self.instructions.append((op, val))
    
    def execute_next(self):
        op, val = self.instructions[self.current_location]
        print(self.current_location, op, val, self.acc)
        assert op in ('nop','acc','jmp')
        k = 1
        if op == 'jmp':
            k = val
        if op == 'acc':
            self.acc += val
        next_index = self.current_location + k
        
        assert 0 <= next_index < len(self.instructions)
        
        self.visited.add(self.current_location)
        
        if next_index in self.visited:
            raise Exception("Loop encountered")
        self.last_executed, self.current_location = self.current_location, next_index
    
    def execute(self):
        while True:
            self.execute_next()

# %%
with open('input.txt', 'r') as f:
    code_str = f.read()

ex = ExecutionGraph(code_str)
ex.execute()
# Out:
# 0 jmp 1 0
# 1 acc -18 0
# 2 acc 19 -18
# 3 acc 19 1
# 4 jmp 202 20
# 206 acc 4 20
# 207 acc 38 24
# 208 acc 49 62
# 209 jmp -94 111
# 115 acc 31 111
# 116 jmp 220 142
# 336 jmp 172 142
# 508 acc 12 142
# 509 jmp 44 154
# 553 acc 4 154
# 554 nop -102 158
# 555 jmp -316 158
# 239 acc 35 158
# 240 acc 31 193
# 241 jmp -139 224
# 102 jmp 370 224
# 472 acc -2 224
# 473 acc 7 222
# 474 acc 4 229
# 475 jmp -10 233
# 465 acc -18 233
# 466 acc -6 215
# 467 acc 33 209
# 468 acc 36 242
# 469 jmp 80 278
# 549 acc -13 278
# 550 acc -13 265
# 551 jmp -360 252
# 191 acc 19 252
# 192 nop 116 271
# 193 acc 32 271
# 194 acc 21 303
# 195 jmp 16 324
# 211 acc 0 324
# 212 acc 9 324
# 213 jmp 224 333
# 437 acc 45 333
# 438 acc -18 378
# 439 acc 23 360
# 440 acc -17 383
# 441 jmp -37 366
# 404 acc 27 366
# 405 acc -2 393
# 406 acc 16 391
# 407 acc 40 407
# 408 jmp -81 447
# 327 jmp -95 447
# 232 acc 10 447
# 233 acc 6 457
# 234 jmp 323 463
# 557 acc 4 463
# 558 nop -487 467
# 559 jmp -339 467
# 220 jmp 265 467
# 485 jmp 1 467
# 486 acc 34 467
# 487 nop 62 501
# 488 jmp -363 501
# 125 acc 13 501
# 126 acc 0 514
# 127 acc 25 514
# 128 jmp 144 539
# 272 acc -8 539
# 273 jmp -176 531
# 97 acc -14 531
# 98 jmp 145 517
# 243 jmp -193 517
# 50 acc 37 517
# 51 jmp 212 554
# 263 nop 157 554
# 264 acc -4 554
# 265 acc 47 550
# 266 jmp -146 597
# 120 nop 471 597
# 121 acc 6 597
# 122 acc 48 603
# 123 jmp -17 651
# 106 acc 22 651
# 107 acc 37 673
# 108 acc 44 710
# 109 jmp 334 754
# 443 nop -302 754
# 444 acc -19 754
# 445 acc -16 735
# 446 jmp -297 719
# 149 nop 370 719
# 150 acc 2 719
# 151 acc -10 721
# 152 acc -7 711
# 153 jmp 224 704
# 377 acc -11 704
# 378 acc 40 693
# 379 jmp 101 733
# 480 acc 24 733
# 481 jmp 144 757
# 625 jmp -192 757
# 433 acc 0 757
# 434 acc -12 757
# 435 jmp -371 745
# 64 acc 10 745
# 65 jmp 285 755
# 350 nop -54 755
# 351 nop 47 755
# 352 acc -11 755
# 353 jmp 18 744
# 371 acc 8 744
# 372 jmp -31 752
# 341 nop 44 752
# 342 nop -99 752
# 343 nop 238 752
# 344 jmp 195 752
# 539 nop -25 752
# 540 acc 0 752
# 541 jmp -84 752
# 457 acc -18 752
# 458 acc -14 734
# 459 acc 6 720
# 460 nop -27 726
# 461 jmp -101 726
# 360 jmp -319 726
# 41 acc 37 726
# 42 jmp 254 763
# 296 acc 3 763
# 297 acc 0 766
# 298 nop 318 766
# 299 jmp 215 766
# 514 acc 33 766
# 515 acc -4 799
# 516 acc 15 795
# 517 jmp 9 810
# 526 acc 8 810
# 527 acc 40 818
# 528 acc 48 858
# 529 jmp 2 906
# 531 nop -325 906
# 532 acc -4 906
# 533 acc 16 902
# 534 acc -4 918
# 535 jmp -369 914
# 166 acc 5 914
# 167 jmp 1 919
# 168 jmp 467 919
# 635 acc 28 919
# 636 jmp -305 947
# 331 acc 7 947
# 332 jmp -24 954
# 308 acc -1 954
# 309 jmp -25 953
# 284 acc 21 953
# 285 acc 26 974
# 286 acc 31 1000
# 287 jmp -231 1031
# 56 acc 5 1031
# 57 nop 134 1036
# 58 acc 46 1036
# 59 jmp 541 1082
# 600 acc -5 1082
# 601 acc 35 1077
# 602 nop -204 1112
# 603 jmp -175 1112
# 428 acc 36 1112
# 429 jmp -270 1148
# 159 jmp 11 1148
# 170 nop 421 1148
# 171 jmp 243 1148
# 414 nop -171 1148
# 415 acc 47 1148
# 416 jmp 169 1195
# 585 acc 16 1195
# 586 acc 39 1211
# 587 acc 49 1250
# 588 jmp -560 1299
# 28 acc 2 1299
# 29 nop 375 1301
# 30 acc 31 1301
# 31 acc 6 1332
# 32 jmp 420 1338
# 452 jmp 114 1338
# 566 acc 22 1338
# 567 acc 32 1360
# 568 jmp -290 1392
# 278 acc 32 1392
# 279 acc 39 1424
# 280 nop 313 1463
# 281 acc 38 1463
# 282 jmp -237 1501
# 45 jmp 458 1501
# 503 acc 6 1501
# 504 acc -11 1507
# 505 jmp -321 1496
# 184 acc 46 1496
# 185 acc 23 1542
# 186 nop -122 1565
# 187 acc 21 1565
# 188 jmp -55 1586
# 133 acc -10 1586
# 134 acc 34 1576
# 135 jmp 168 1610
# 303 jmp 33 1610
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-21-915bf7787e4e> in <module>
#       3
#       4 ex = ExecutionGraph(code_str)
# ----> 5 ex.execute()
#
# <ipython-input-20-56a9ee20b8c7> in execute(self)
#      47     def execute(self):
#      48         while True:
# ---> 49             self.execute_next()
#
# <ipython-input-20-56a9ee20b8c7> in execute_next(self)
#      42
#      43         if next_index in self.visited:
# ---> 44             raise Exception("Loop encountered")
#      45         self.last_executed, self.current_location = self.current_location, next_index
#      46
#
# Exception: Loop encountered

# %% [markdown]
# # Part 2

# %%
candidates = [i for i in ex.visited if ex.instructions[i][0] in ('nop', 'jmp')]
len(candidates)
# Out:
# 94
